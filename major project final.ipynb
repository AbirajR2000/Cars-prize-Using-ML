# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Cars.csv')

# %%
# Understanding the data given in the sheet

# %%
df.head()
# Out:
#                Name   Location    Year  Kilometers_Driven Fuel_Type  \
# 0  Mahindra Scorpio       Pune  2012.0            99000.0    Diesel
# 1     Maruti Baleno      Kochi  2018.0            18678.0    Petrol
# 2     Mahindra Xylo  Bangalore  2013.0           197000.0    Diesel
# 3     Hyundai Grand      Delhi  2014.0            45000.0    Diesel
# 4     Toyota Innova      Delhi  2011.0            65000.0    Diesel
#
#   Transmission Owner_Type     Mileage   Engine    Power        Colour  Seats  \
# 0       Manual      Third  12.05 kmpl  2179 CC  120 bhp  Black/Silver    8.0
# 1       Manual      First   21.1 kmpl   998 CC  100 bhp        Others    5.0
# 2       Manual      First  11.68 kmpl  2498 CC  112 bhp         White    7.0
# 3       Manual      First   24.0 kmpl  1120 CC   70 bhp         White    5.0
# 4       Manual      First   12.8 kmpl  2494 CC  102 bhp        Others    8.0
#
#    No. of Doors New_Price  Price
# 0           5.0       NaN   6.00
# ...

# %%
df.tail()
# Out:
#                          Name    Location    Year  Kilometers_Driven  \
# 5956              Honda Civic        Pune  2011.0            47000.0
# 5957              Hyundai i20       Delhi  2013.0            63777.0
# 5958             Maruti Swift  Coimbatore  2016.0            37806.0
# 5959  Mercedes-Benz SLK-Class  Coimbatore  2016.0            22732.0
# 5960              Hyundai i10     Kolkata  2016.0             7000.0
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  \
# 5956    Petrol    Automatic     Second   13.9 kmpl  1799 CC  130.3 bhp
# 5957    Petrol       Manual      First   18.5 kmpl  1197 CC   82.9 bhp
# 5958    Petrol       Manual      First   20.4 kmpl  1197 CC  81.80 bhp
# 5959    Petrol    Automatic      First   18.1 kmpl  3498 CC    306 bhp
# 5960    Petrol       Manual      First  20.36 kmpl  1197 CC   78.9 bhp
#
#             Colour  Seats  No. of Doors New_Price  Price
# 5956        Others    5.0           4.0       NaN   4.50
# ...

# %%
df.describe()
# Out:
#               Year  Kilometers_Driven        Seats  No. of Doors        Price
# count  5959.000000       5.953000e+03  5956.000000   5960.000000  5961.000000
# mean   2013.389159       5.871110e+04     5.269140      4.114933     9.528103
# std       3.243051       9.171221e+04     0.789048      0.344757    11.214382
# min    1998.000000       1.710000e+02     2.000000      2.000000     0.440000
# 25%    2011.500000       3.393100e+04     5.000000      4.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000      4.000000     5.660000
# 75%    2016.000000       7.300000e+04     5.000000      4.000000    10.000000
# max    2019.000000       6.500000e+06    10.000000      5.000000   160.000000

# %%
df.shape
# Out:
# (5961, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Colour',
#        'Seats', 'No. of Doors', 'New_Price', 'Price'],
#       dtype='object')

# %%
df = df[['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
       'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', #'Colour',
       #'Seats', 'No. of Doors', 
     'New_Price', 'Price']].copy()

# %%
df.shape
# Out:
# (5961, 12)

# %%
# total no of columns present in the dataset after drop out some columns
df.nunique()
# Out:
# Name                  212
# Location               11
# Year                   22
# Kilometers_Driven    3068
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               439
# Engine                143
# Power                 369
# New_Price             540
# Price                1369
# dtype: int64

# %%
# the name of the total cars which are given in the dataset
df['Name'].unique()
# Out:
# array(['Mahindra Scorpio', 'Maruti Baleno', 'Mahindra Xylo',
#        'Hyundai Grand', 'Toyota Innova', 'Honda WRV', 'Hyundai Verna',
#        'Toyota Fortuner', 'Chevrolet Beat', 'Audi A6', 'Hyundai i20',
#        'Skoda Laura', 'Honda City', 'Audi Q7', 'Renault Duster',
#        'Maruti Ertiga', 'Land Rover Freelander', 'Skoda Rapid',
#        'Maruti Zen', 'BMW 3', 'Maruti Wagon', 'Honda Jazz',
#        'Maruti Vitara', 'ISUZU D-MAX', 'Maruti SX4', 'Hyundai i10',
#        'Honda Amaze', 'Hyundai Xcent', 'Jaguar F',
#        'Mercedes-Benz C-Class', 'Volkswagen Polo', 'BMW 5',
#        'Mahindra Thar', 'Maruti Alto', 'Audi A3', 'Tata Xenon', 'BMW X1',
#        'Hyundai Getz', 'Volkswagen Vento', 'Chevrolet Sail',
#        'Volkswagen Jetta', 'Maruti Ciaz', 'Honda CR-V', 'Mahindra XUV500',
#        'Mercedes-Benz New', 'Honda Civic', 'Skoda Superb', 'Maruti Ritz',
#        'Mitsubishi Pajero', 'Toyota Corolla', 'Hyundai Elantra',
# ...

# %%
# cleaning the dataset

# %%
df.isnull()
# Out:
#        Name  Location   Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0     False     False  False              False      False         False
# 1     False     False  False              False      False         False
# 2     False     False  False              False      False         False
# 3     False     False  False              False      False         False
# 4     False     False  False              False      False         False
# ...     ...       ...    ...                ...        ...           ...
# 5956  False     False  False              False      False         False
# 5957  False     False  False              False      False         False
# 5958  False     False  False              False      False         False
# 5959  False     False  False              False      False         False
# 5960  False     False  False              False      False         False
#
#       Owner_Type  Mileage  Engine  Power  New_Price  Price
# ...

# %%
# to find out the null cell in the given data set
df.isnull().sum()
# Out:
# Name                    0
# Location               11
# Year                    2
# Kilometers_Driven       8
# Fuel_Type               0
# Transmission           27
# Owner_Type             15
# Mileage                 2
# Engine                 17
# Power                  32
# New_Price            5137
# Price                   0
# dtype: int64

# %%
# it can represent the first five rows of the data set
df.head()
# Out:
#                Name   Location    Year  Kilometers_Driven Fuel_Type  \
# 0  Mahindra Scorpio       Pune  2012.0            99000.0    Diesel
# 1     Maruti Baleno      Kochi  2018.0            18678.0    Petrol
# 2     Mahindra Xylo  Bangalore  2013.0           197000.0    Diesel
# 3     Hyundai Grand      Delhi  2014.0            45000.0    Diesel
# 4     Toyota Innova      Delhi  2011.0            65000.0    Diesel
#
#   Transmission Owner_Type     Mileage   Engine    Power New_Price  Price
# 0       Manual      Third  12.05 kmpl  2179 CC  120 bhp       NaN   6.00
# 1       Manual      First   21.1 kmpl   998 CC  100 bhp       NaN   8.32
# 2       Manual      First  11.68 kmpl  2498 CC  112 bhp       NaN   4.00
# 3       Manual      First   24.0 kmpl  1120 CC   70 bhp       NaN   3.49
# 4       Manual      First   12.8 kmpl  2494 CC  102 bhp       NaN   6.40

# %%
df.dropna(inplace = True)
print(df.to_string())
# Out:
#                        Name    Location    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine       Power   New_Price   Price
# 5                 Honda WRV       Kochi  2018.0            15135.0    Petrol       Manual      First    17.5 kmpl  1199 CC    88.7 bhp  10.57 Lakh    9.29
# 22                    BMW 3      Mumbai  2014.0            48000.0    Diesel    Automatic      First   21.76 kmpl  1995 CC     190 bhp  60.88 Lakh   26.50
# 27            Maruti Vitara  Coimbatore  2018.0            64456.0    Diesel       Manual      First    24.3 kmpl  1248 CC    88.5 bhp     11 Lakh   10.46
# 32             Maruti Wagon       Kochi  2011.0            15466.0    Petrol       Manual      First    22.5 kmpl   998 CC   67.04 bhp   5.04 Lakh    3.36
# 36    Mercedes-Benz C-Class      Mumbai  2018.0             8682.0    Diesel    Automatic      First     0.0 kmpl  1950 CC     194 bhp  52.26 Lakh   39.50
# ...

# %%
# relationship analysis

# %%
df = pd.read_csv('Cars.csv')
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5956    False
# 5957    False
# 5958    False
# 5959    False
# 5960    False
# Length: 5961, dtype: bool

# %%
# This graph represents the overall Kilometers Driven, Years and Prices of the cars
sns.pairplot(df)

# %%
# This shows the huge varity of cars with there compnies
sns.relplot(x='Year',y='Kilometers_Driven', hue='Name',data=df)
plt.show()

# %%
# This shows that the price and owner type of the cars 
sns.relplot(x='Price',y='Kilometers_Driven',hue='Owner_Type',data=df)
plt.show()

# %%
# this graph shows that which car having more sales
sns.histplot(df['Name'])
plt.show()

# %%
# this graph show that the sales of the second hand cars each year
sns.histplot(df['Year'])
plt.show()

# %%
# this graph can show the no. of cars sales in particular locations
sns.histplot(df['Location'])
plt.show()

# %%
# sales of cars according to the fuel type 
# Diesel cars having more sales than any other
sns.catplot(x='Price',y='Fuel_Type',data=df)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#                          Name    Location    Year  Kilometers_Driven  \
# 0            Mahindra Scorpio        Pune  2012.0            99000.0
# 1               Maruti Baleno       Kochi  2018.0            18678.0
# 2               Mahindra Xylo   Bangalore  2013.0           197000.0
# 3               Hyundai Grand       Delhi  2014.0            45000.0
# 4               Toyota Innova       Delhi  2011.0            65000.0
# ...                       ...         ...     ...                ...
# 5956              Honda Civic        Pune  2011.0            47000.0
# 5957              Hyundai i20       Delhi  2013.0            63777.0
# 5958             Maruti Swift  Coimbatore  2016.0            37806.0
# 5959  Mercedes-Benz SLK-Class  Coimbatore  2016.0            22732.0
# 5960              Hyundai i10     Kolkata  2016.0             7000.0
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  \
# ...

# %%
numeric_columns= numeric_columns = df.select_dtypes(include=np.number).columns.tolist()
plt.figure(figsize=(13,17))

for i, variable in enumerate(numeric_columns):
                     plt.subplot(5,2,i+1)
                     sns.scatterplot(x=df[variable],y=df['Price']).set(title='Price vs '+ variable)
                     #plt.xticks(rotation=90)
                     plt.tight_layout()
plt.show()

# %%
cat_columns=['Location','Fuel_Type','Transmission', 'Owner_Type'] #cars.select_dtypes(exclude=np.number).columns.tolist()

plt.figure(figsize=(15,21))

for i, variable in enumerate(cat_columns):
                     plt.subplot(4,2,i+1)
                     order = df[variable].value_counts(ascending=False).index
                     ax=sns.countplot(x=df[variable], data=df , order=order ,palette='viridis')
                     for p in ax.patches:
                           percentage = '{:.1f}%'.format(100 * p.get_height()/len(df[variable]))
                           x = p.get_x() + p.get_width() / 2 - 0.05
                           y = p.get_y() + p.get_height()
                           plt.annotate(percentage, (x, y),ha='center')
                     plt.xticks(rotation=90)
                     plt.tight_layout()
                     plt.title(variable)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.title("Price based on manufacturing Year of model")
sns.lineplot(x='Year', y='Price',hue='Transmission',
             data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'correlation' is the DataFrame containing the correlation matrix
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
# Assuming df is your DataFrame
numeric_columns = df.select_dtypes(include='number')
correlation = numeric_columns.corr()

# Now, 'correlation' contains the correlation matrix for numeric columns.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Assuming df is your DataFrame

for i in df.columns:
    try:
        sns.boxplot(x=df[i])
        plt.title(f'Boxplot for {i}')
        plt.show()
    except Exception as e:
        print(f"{i} is a categorical variable or an issue occurred: {e}")
# Out:
# Name is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# Location is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# Fuel_Type is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# Transmission is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# Owner_Type is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# Mileage is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# Engine is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# Power is a categorical variable or an issue occurred: Horizontal orientation requires numeric `x` variable.
# ...

# %%
df.drop('New_Price', axis=1, inplace=True)

# %%
df.head()
# Out:
#                Name   Location    Year  Kilometers_Driven Fuel_Type  \
# 0  Mahindra Scorpio       Pune  2012.0            99000.0    Diesel
# 1     Maruti Baleno      Kochi  2018.0            18678.0    Petrol
# 2     Mahindra Xylo  Bangalore  2013.0           197000.0    Diesel
# 3     Hyundai Grand      Delhi  2014.0            45000.0    Diesel
# 4     Toyota Innova      Delhi  2011.0            65000.0    Diesel
#
#   Transmission Owner_Type     Mileage   Engine    Power        Colour  Seats  \
# 0       Manual      Third  12.05 kmpl  2179 CC  120 bhp  Black/Silver    8.0
# 1       Manual      First   21.1 kmpl   998 CC  100 bhp        Others    5.0
# 2       Manual      First  11.68 kmpl  2498 CC  112 bhp         White    7.0
# 3       Manual      First   24.0 kmpl  1120 CC   70 bhp         White    5.0
# 4       Manual      First   12.8 kmpl  2494 CC  102 bhp        Others    8.0
#
#    No. of Doors  Price
# 0           5.0   6.00
# 1           4.0   8.32
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df_no_outliers = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# Now df_no_outliers contains the DataFrame with outliers removed

# %%
df.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Colour',
#        'Seats', 'No. of Doors', 'Price'],
#       dtype='object')

# %%
q1 = df["Year"].quantile(0.25)
q3 = df["Year"].quantile(0.75)
IQR = q3 - q1
IQR = 1.5 * IQR
ll = q1 - IQR
ul = q3 + IQR
print(ll , ul)
# Out:
# 2004.75 2022.75

# %%
df = df[(df.Year > ll) & (df.Year < ul)]

# %%
q1 = df["Kilometers_Driven"].quantile(0.25)
q3 = df["Kilometers_Driven"].quantile(0.75)
IQR = q3 - q1
IQR = 1.5 * IQR
ll = q1 - IQR
ul = q3 + IQR
print(ll , ul)
# Out:
# -24469.25 130204.75

# %%
df = df[(df.Kilometers_Driven > ll) & (df.Kilometers_Driven < ul)]

# %%
q1 = df["Seats"].quantile(0.25)
q3 = df["Seats"].quantile(0.75)
IQR = q3 - q1
IQR = 1.5 * IQR
ll = q1 - IQR
ul = q3 + IQR
print(ll , ul)
# Out:
# 5.0 5.0

# %%
df = df[(df.Seats > ll) & (df.Seats < ul)]

# %%
q1 = df["No. of Doors"].quantile(0.25)
q3 = df["No. of Doors"].quantile(0.75)
IQR = q3 - q1
IQR = 1.5 * IQR
ll = q1 - IQR
ul = q3 + IQR
print(ll , ul)
# Out:
# nan nan

# %%
df = df[(df.No. of Doors > ll) & (df.No. of Doors < ul)]
# Out:
#   File "C:\Users\abira\AppData\Local\Temp\ipykernel_24432\954563139.py", line 1
#     df = df[(df.No. of Doors > ll) & (df.No. of Doors < ul)]
#                        ^
# SyntaxError: invalid syntax

# %%
q1 = df["Price"].quantile(0.25)
q3 = df["Price"].quantile(0.75)
IQR = q3 - q1
IQR = 1.5 * IQR
ll = q1 - IQR
ul = q3 + IQR
print(ll , ul)
# Out:
# nan nan

# %%
df.isnull().sum()
# Out:
# Name                 0.0
# Location             0.0
# Year                 0.0
# Kilometers_Driven    0.0
# Fuel_Type            0.0
# Transmission         0.0
# Owner_Type           0.0
# Mileage              0.0
# Engine               0.0
# Power                0.0
# Colour               0.0
# Seats                0.0
# No. of Doors         0.0
# Price                0.0
# dtype: float64

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic', nan], dtype=object)

# %%
print(X.shape)
print(y.shape)
# Out:
# (0, 13)
# (0,)

# %%
df.interpolate(method='ffill', axis='columns', limit=1, inplace=True, limit_direction='forward', limit_area='inside', downcast=None)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
df = pd.DataFrame({
    'A': [1, 2, np.nan, 4],
    'B': [5, np.nan, 7, 8],
    'C': [9, 10, 11, 12]
})

# Remove rows containing NaN values
df_cleaned_rows = df.dropna()

# Display the DataFrame without NaN values in rows
print(df_cleaned_rows)
# Out:
#      A    B   C
# 0  1.0  5.0   9
# 3  4.0  8.0  12

# %%
import pandas as pd
import numpy as np

# Assuming you want to create a DataFrame
data = {
    'A': [np.nan, 7.0, 11],
    'B': [5, np.nan, 7],
    'C': [9, 10, 11]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#       A    B   C
# 0   NaN  5.0   9
# 1   7.0  NaN  10
# 2  11.0  7.0  11

# %%
# Remove columns containing NaN values
df_cleaned_columns = df.dropna(axis=1)

# Display the DataFrame without NaN values in columns
print(df_cleaned_columns)
# Out:
#     C
# 0   9
# 1  10
# 2  11

# %%
# Remove rows where NaN appears in specific columns
df_cleaned_specific_columns = df.dropna(subset=['A', 'B'])

# Display the DataFrame without NaN values in specific columns
print(df_cleaned_specific_columns)
# Out:
#       A    B   C
# 2  11.0  7.0  11

# %%
df.describe()
# Out:
#                A         B     C
# count   2.000000  2.000000   3.0
# mean    9.000000  6.000000  10.0
# std     2.828427  1.414214   1.0
# min     7.000000  5.000000   9.0
# 25%     8.000000  5.500000   9.5
# 50%     9.000000  6.000000  10.0
# 75%    10.000000  6.500000  10.5
# max    11.000000  7.000000  11.0

# %% [markdown]
# df.isnull().sum()

# %%
df.isnull().sum()
# Out:
# A    1
# B    1
# C    0
# dtype: int64

# %%
df.head()
# Out:
#                Name   Location    Year  Kilometers_Driven Fuel_Type  \
# 0  Mahindra Scorpio       Pune  2012.0            99000.0    Diesel
# 1     Maruti Baleno      Kochi  2018.0            18678.0    Petrol
# 2     Mahindra Xylo  Bangalore  2013.0           197000.0    Diesel
# 3     Hyundai Grand      Delhi  2014.0            45000.0    Diesel
# 4     Toyota Innova      Delhi  2011.0            65000.0    Diesel
#
#   Transmission Owner_Type     Mileage   Engine    Power        Colour  Seats  \
# 0       Manual      Third  12.05 kmpl  2179 CC  120 bhp  Black/Silver    8.0
# 1       Manual      First   21.1 kmpl   998 CC  100 bhp        Others    5.0
# 2       Manual      First  11.68 kmpl  2498 CC  112 bhp         White    7.0
# 3       Manual      First   24.0 kmpl  1120 CC   70 bhp         White    5.0
# 4       Manual      First   12.8 kmpl  2494 CC  102 bhp        Others    8.0
#
#    No. of Doors New_Price  Price
# 0           5.0       NaN   6.00
# ...

# %%
from sklearn.impute import SimpleImputer

# Identify numerical columns
numerical_cols = X.select_dtypes(include=['number']).columns

# Create a column transformer for preprocessing with imputation
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_cols),
        ('cat', OneHotEncoder(), categorical_cols)
    ],
    remainder='passthrough'
)

# %%
from sklearn.preprocessing import StandardScaler

# Add StandardScaler to the numerical transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(), categorical_cols)
    ],
    remainder='passthrough'
)

# %%
X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.fillna(1e10, inplace=True)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Assuming 'df' is your DataFrame with both numerical and categorical columns
# 'target_column' is your target variable

# Separate features and target variable
X = df.drop('Price', axis=1)
y = df['Price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Identify categorical columns
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(include=['number']).columns

# Create a column transformer for preprocessing with imputation
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_cols),
        ('cat', OneHotEncoder(), categorical_cols)
    ],
    remainder='passthrough'
)

# Create a pipeline with preprocessing and linear regression
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Fit the model
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', SimpleImputer(),
#                                                   Index(['Year', 'Kilometers_Driven', 'Seats', 'No. of Doors'], dtype='object')),
#                                                  ('cat', OneHotEncoder(),
#                                                   Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Engine', 'Power', 'Colour', 'New_Price'],
#       dtype='object'))])),
#                 ('regressor', LinearRegression())])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', SimpleImputer(),
#                                                   Index(['Year', 'Kilometers_Driven', 'Seats', 'No. of Doors'], dtype='object')),
#                                                  ('cat', OneHotEncoder(),
#                                                   Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type',
#        'Mileage', 'Engine', 'Power', 'Colour', 'New_Price'],
#       dtype='object'))])),
#                 ('regressor', LinearRegression())])

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Assuming 'df' is your DataFrame with both numerical and categorical columns
# 'target_column' is your target variable

# Separate features and target variable
X = df.drop('Price', axis=1)
y = df['Price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Identify categorical columns
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(include=['number']).columns

# Create a column transformer for preprocessing with imputation
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ],
    remainder='passthrough'
)

# Create a pipeline with preprocessing and linear regression
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Fit the model
model.fit(X_train, y_train)

# Make predictions on the new data
predictions = model.predict(X_test)

# Display or use the predictions as needed
print(predictions)
# Out:
# [15.52584208 22.46518364  0.02471373 ... 14.63446953  9.13166904
#   8.41026454]

# %%
from sklearn.metrics import r2_score

# Assuming 'y_test' contains the actual target values
r2 = r2_score(y_test, predictions)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.4807429980469615

# %%
X_train_encoded = X_train_encoded.fillna(0)  # Replace NaN with 0, adjust as needed

# %%
import numpy as np

X_train_encoded = np.nan_to_num(X_train_encoded, nan=0, posinf=1e9, neginf=-1e9)

# %%
print(y_train.unique())
# Out:
# [29.4   0.7   3.9  ... 28.9  30.77  3.58]

# %%
from sklearn.ensemble import RandomForestRegressor

# Update the regressor in the pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=100, random_state=1))  # You can adjust hyperparameters
])

# Fit the model
model.fit(X_train, y_train)

# Make predictions on the new data
prediction1 = model.predict(X_test)

# Display or use the predictions as needed
print(prediction1)
# Out:
# [ 4.0358 12.9342  1.5621 ... 42.5231  3.48    5.8256]

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# Calculate metrics
mae = mean_absolute_error(y_test, prediction1)

r2 = r2_score(y_test, predictions)

# Display metrics
print(f'Mean Absolute Error: {mae}')

print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 1.855533459101919
# R-squared: 0.8264778155860134
